# %%
# !git clone https://github.com/reachsumit/deep-unet-for-satellite-image-segmentation.git
# Out:
# Cloning into 'deep-unet-for-satellite-image-segmentation'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 92 (delta 12), reused 10 (delta 10), pack-reused 71
# Unpacking objects: 100% (92/92), 144.86 MiB | 10.39 MiB/s, done.
# Updating files: 100% (61/61), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/tensorflow/tensorflow.git
# Out:
# Cloning into 'tensorflow'...
# remote: Enumerating objects: 1555365, done.
# remote: Counting objects: 100% (770/770), done.
# remote: Compressing objects: 100% (450/450), done.
# remote: Total 1555365 (delta 388), reused 643 (delta 318), pack-reused 1554595
# Receiving objects: 100% (1555365/1555365), 977.96 MiB | 18.27 MiB/s, done.
# Resolving deltas: 100% (1260840/1260840), done.
# Updating files: 100% (29367/29367), done.

# %%
# !python3 /content/deep-unet-for-satellite-image-segmentation/train_unet.py
# Out:
# 2023-04-05 02:35:50.986565: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 02:35:51.921068: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Reading images
# Traceback (most recent call last):
#   File "/content/deep-unet-for-satellite-image-segmentation/train_unet.py", line 52, in <module>
#     mask = tiff.imread('/content/deep-unet-for-satellite-image-segmentation/data/gt_mband/{}.tif'.format(img_id)).transpose([1, 2, 0]) / 255
# ValueError: axes don't match array

# %%
# !python3 /content/drive/MyDrive/deep-unet-for-satellite-image-segmentation-master/deep-unet-for-satellite-image-segmentation-master/predict.py
# Out:
# python3: can't open file '/content/drive/MyDrive/deep-unet-for-satellite-image-segmentation-master/deep-unet-for-satellite-image-segmentation-master/predict.py': [Errno 2] No such file or directory
